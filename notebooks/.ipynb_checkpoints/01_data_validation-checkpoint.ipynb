# %%
# 验证路径设置
import os
import sys

# 自动计算项目根目录
current_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(current_dir, ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    
# 打印当前环境路径
print(f"Python executable: {sys.executable}")
print(f"Project root: {project_root}")

# 导入模块
try:
    from src.data_ingestion.downloader import StockDownloader
    print("✅ 模块导入成功！")
except ImportError as e:
    print(f"❌ 导入失败: {str(e)}")
    print("当前 Python 路径：", sys.path)
# Out:
# Python executable: /opt/anaconda3/envs/quant/bin/python
# Project root: /Users/zhengyi/stock_project
# ✅ 模块导入成功！

# %%
# notebooks/01_data_validation.ipynb
test_tickers = ['AAPL', 'MSFT', '000001.SZ']  # 包含A股测试代码
downloader = StockDownloader(test_tickers)
raw_data = downloader.parallel_download()
assert not raw_data.isnull().sum().any(), "存在缺失数据"
